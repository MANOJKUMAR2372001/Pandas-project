# %% [markdown]
# ELECTRICAL VEHICLE SALES ANALYSIS

# %%
import pandas as pd

# %%
df=pd.read_csv("ev_sales_dataset_cleaned.csv")

# %%
df
# Out:
#                                    Sale_ID Date_of_Sale Vehicle_Make  \
# 0     19985f15-ff00-4d4d-9020-59e4ff9ab5c2   2023-10-04   Volkswagen
# 1     8181a8cc-3691-47eb-89a2-688b12c136e0   2022-03-31         Ford
# 2     5958a499-eeea-463e-a1e8-ac6843e42caf   2022-09-15          BMW
# 3     3e896c64-e117-4ac3-919c-4ea3e1805081   2022-09-10   Volkswagen
# 4     702cdd20-2862-48b8-88f4-ef125e9953d2   2022-07-19    Chevrolet
# ...                                    ...          ...          ...
# 3995  c69e17c9-6018-4b17-bec5-715ca71db3a6   2022-05-13       Rivian
# 3996  abb558e1-cb9a-4ed5-bdbc-ebdbb119779c   2022-09-17         Ford
# 3997  76b35303-c719-4dd0-96f0-c19ca894b11e   2024-04-11       Nissan
# 3998  61d15db2-a67a-470a-9175-3cd1dd69cf6b   2024-02-25      Hyundai
# 3999  71f34593-a737-419b-a1e0-9bf146748ee4   2023-10-04      Hyundai
#
#        Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# ...

# %%
df.head()
# Out:
#                                 Sale_ID Date_of_Sale Vehicle_Make  \
# 0  19985f15-ff00-4d4d-9020-59e4ff9ab5c2   2023-10-04   Volkswagen
# 1  8181a8cc-3691-47eb-89a2-688b12c136e0   2022-03-31         Ford
# 2  5958a499-eeea-463e-a1e8-ac6843e42caf   2022-09-15          BMW
# 3  3e896c64-e117-4ac3-919c-4ea3e1805081   2022-09-10   Volkswagen
# 4  702cdd20-2862-48b8-88f4-ef125e9953d2   2022-07-19    Chevrolet
#
#     Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# 0            ID.4          2021                     107            109
# 1  Mustang Mach-E          2017                      33            111
# 2              iX          2021                      70            362
# 3            ID.4          2022                      74            244
# 4         Bolt EV          2024                      79            291
#
#    Charging_Time_(hours)  Price_(USD)  Buyer_Age Buyer_Gender  \
# 0                    9.8        37517         41       Female
# ...

# %%
df.tail()
# Out:
#                                    Sale_ID Date_of_Sale Vehicle_Make  \
# 3995  c69e17c9-6018-4b17-bec5-715ca71db3a6   2022-05-13       Rivian
# 3996  abb558e1-cb9a-4ed5-bdbc-ebdbb119779c   2022-09-17         Ford
# 3997  76b35303-c719-4dd0-96f0-c19ca894b11e   2024-04-11       Nissan
# 3998  61d15db2-a67a-470a-9175-3cd1dd69cf6b   2024-02-25      Hyundai
# 3999  71f34593-a737-419b-a1e0-9bf146748ee4   2023-10-04      Hyundai
#
#        Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# 3995             R1S          2023                     118            350
# 3996  Mustang Mach-E          2019                      92            328
# 3997            Leaf          2016                      50            289
# 3998         Ioniq 5          2017                      32            223
# 3999   Kona Electric          2023                     111            183
#
#       Charging_Time_(hours)  Price_(USD)  Buyer_Age Buyer_Gender  \
# ...

# %%
df.shape
# Out:
# (4000, 15)

# %%
df.columns
# Out:
# Index(['Sale_ID', 'Date_of_Sale', 'Vehicle_Make', 'Vehicle_Model',
#        'Vehicle_Year', 'Battery_Capacity_(kWh)', 'Range_(miles)',
#        'Charging_Time_(hours)', 'Price_(USD)', 'Buyer_Age', 'Buyer_Gender',
#        'Location', 'Payment_Method', 'Dealer_Name',
#        'Customer_Satisfaction_Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sale_ID                       4000 non-null   object
#  1   Date_of_Sale                  4000 non-null   object
#  2   Vehicle_Make                  4000 non-null   object
#  3   Vehicle_Model                 4000 non-null   object
#  4   Vehicle_Year                  4000 non-null   int64
#  5   Battery_Capacity_(kWh)        4000 non-null   int64
#  6   Range_(miles)                 4000 non-null   int64
#  7   Charging_Time_(hours)         4000 non-null   float64
#  8   Price_(USD)                   4000 non-null   int64
#  9   Buyer_Age                     4000 non-null   int64
#  10  Buyer_Gender                  4000 non-null   object
#  11  Location                      4000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Sale_ID                         0
# Date_of_Sale                    0
# Vehicle_Make                    0
# Vehicle_Model                   0
# Vehicle_Year                    0
# Battery_Capacity_(kWh)          0
# Range_(miles)                   0
# Charging_Time_(hours)           0
# Price_(USD)                     0
# Buyer_Age                       0
# Buyer_Gender                    0
# Location                        0
# Payment_Method                  0
# Dealer_Name                     0
# Customer_Satisfaction_Rating    0
# dtype: int64

# %%
df[["Location","Vehicle_Make","Vehicle_Model","Buyer_Gender"]].nunique()
# Out:
# Location         50
# Vehicle_Make      8
# Vehicle_Model    17
# Buyer_Gender      3
# dtype: int64

# %%
df["Location"].unique()
# Out:
# array(['Jamesmouth, KS', 'Meaganhaven, ID', 'North Richardmouth, CT',
#        'East Donna, GA', 'Lake Larry, SD', 'Jasonview, TX',
#        'Port Erin, CA', 'Samuelhaven, DE', 'Lake Jenniferside, KY',
#        'South Christianport, SC', 'Jasonfort, SD', 'Lake Nancyview, WV',
#        'Curtisfurt, MI', 'North Collin, MI', 'Coxberg, NM',
#        'Lake Mark, WI', 'Allisonchester, ND', 'Lawrencetown, GA',
#        'New Rita, SC', 'Port Brandonville, SC', 'Petersonberg, WV',
#        'Johnbury, OK', 'Whitemouth, CA', 'East Carloston, MA',
#        'North Jessicaland, ND', 'Lake Selena, OK', 'East Lydiamouth, KY',
#        'New Mariotown, MN', 'Danielchester, NH', 'Sanchezfort, MT',
#        'Thomasberg, WA', 'Mortonside, AR', 'Cassandraton, NH',
#        'New Cynthiaside, IA', 'East Caleb, OR', 'Juliechester, OR',
#        'South Noah, UT', 'North Judithbury, DC', 'East Robinshire, VT',
#        'Barbaraland, TN', 'Jenkinston, SD', 'West Kathryn, WI',
# ...

# %%
df["Vehicle_Make"].unique()
# Out:
# array(['Volkswagen', 'Ford', 'BMW', 'Chevrolet', 'Rivian', 'Nissan',
#        'Hyundai', 'Tesla'], dtype=object)

# %%
df["Vehicle_Make"].value_counts()
# Out:
# Vehicle_Make
# BMW           523
# Ford          517
# Tesla         513
# Hyundai       505
# Nissan        504
# Volkswagen    488
# Rivian        481
# Chevrolet     469
# Name: count, dtype: int64

# %%
top=df["Vehicle_Make"].value_counts().idxmax()

# %%
top
# Out:
# 'BMW'

# %%
print(f"the highest sold out vehicle is {top}")
# Out:
# the highest sold out vehicle is BMW

# %%
df["Vehicle_Model"].unique()
# Out:
# array(['ID.4', 'Mustang Mach-E', 'iX', 'Bolt EV', 'R1T', 'i4', 'Leaf',
#        'Bolt EUV', 'R1S', 'Ioniq 5', 'Kona Electric', 'Model 3', 'i3',
#        'Model S', 'Model Y', 'F-150 Lightning', 'Model X'], dtype=object)

# %%
df["Battery_Capacity_(kWh)"].unique()
# Out:
# array([107,  33,  70,  74,  79, 108,  57,  71, 109, 105,  98,  30,  68,
#        119,  46, 117,  64,  75,  78,  91,  67,  52,  51,  88, 102,  97,
#        100, 116,  31,  60,  69,  77,  80,  72,  84,  86, 106,  44,  56,
#         93,  59,  65,  96, 115, 114,  85,  73,  87,  82, 113,  45,  66,
#         50,  48,  47,  81,  36,  63,  95,  39,  89,  37,  94,  38,  90,
#         92,  62,  42,  35,  49,  83,  54,  34,  76,  99,  32, 110, 112,
#        111,  58,  53,  43,  41, 104,  61, 101, 118, 103,  40,  55])

# %%
df["Battery_Capacity_(kWh)"].value_counts().idxmax()
# Out:
# 106

# %%
df["Buyer_Gender"].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df["Buyer_Gender"].value_counts()
# Out:
# Buyer_Gender
# Male      1380
# Other     1328
# Female    1292
# Name: count, dtype: int64

# %%
df["Buyer_Gender"].value_counts().sum()
# Out:
# 4000

# %%
df["Price_(USD)"].agg(["max","min","mean"])
# Out:
# max     89997.0000
# min     25014.0000
# mean    57174.9155
# Name: Price_(USD), dtype: float64

# %%
duplicate = df.duplicated().sum()

# %%
duplicate
# Out:
# 0

# %%
df.loc[0:10]
# Out:
#                                  Sale_ID Date_of_Sale Vehicle_Make  \
# 0   19985f15-ff00-4d4d-9020-59e4ff9ab5c2   2023-10-04   Volkswagen
# 1   8181a8cc-3691-47eb-89a2-688b12c136e0   2022-03-31         Ford
# 2   5958a499-eeea-463e-a1e8-ac6843e42caf   2022-09-15          BMW
# 3   3e896c64-e117-4ac3-919c-4ea3e1805081   2022-09-10   Volkswagen
# 4   702cdd20-2862-48b8-88f4-ef125e9953d2   2022-07-19    Chevrolet
# 5   4d71c366-b41b-4143-8b10-550cd5704f32   2022-09-18       Rivian
# 6   ce9e1a11-fcbb-4e59-bbdd-cf7c9c96e9ec   2024-04-10          BMW
# 7   aaf91531-0200-41f0-8768-a84fa76afde6   2024-12-03          BMW
# 8   ee87905e-4ca4-45ea-8dfa-6a56d12dbc9a   2025-01-14   Volkswagen
# 9   e0ccedc5-f05d-476e-9a84-a51aa9d3d7c7   2024-05-12       Nissan
# 10  e3c43657-1d8c-4bac-83b4-09ef2260e70f   2023-02-25    Chevrolet
#
#      Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# 0             ID.4          2021                     107            109
# ...

# %%
df.loc[(df["Vehicle_Make"]=="Volkswagen") & (df["Payment_Method"]=="Loan")].head()
# Out:
#                                   Sale_ID Date_of_Sale Vehicle_Make  \
# 0    19985f15-ff00-4d4d-9020-59e4ff9ab5c2   2023-10-04   Volkswagen
# 8    ee87905e-4ca4-45ea-8dfa-6a56d12dbc9a   2025-01-14   Volkswagen
# 78   3c20592f-c04a-46c4-b3b6-3fe1d1843324   2024-12-29   Volkswagen
# 84   624c69b6-b244-45a7-b7e5-848131c681ec   2023-06-11   Volkswagen
# 100  46fde062-a33d-47af-9701-410d3f4b1a70   2022-08-13   Volkswagen
#
#     Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# 0            ID.4          2021                     107            109
# 8            ID.4          2020                     109            370
# 78           ID.4          2023                      66            334
# 84           ID.4          2020                     107            327
# 100          ID.4          2022                      70            204
#
#      Charging_Time_(hours)  Price_(USD)  Buyer_Age Buyer_Gender  \
# ...

# %%
data_exp=df.loc[(df["Vehicle_Make"]=="Ford") & (df["Payment_Method"]=="Cash")].head()

# %%
data_exp
# Out:
#                                  Sale_ID Date_of_Sale Vehicle_Make  \
# 1   8181a8cc-3691-47eb-89a2-688b12c136e0   2022-03-31         Ford
# 44  6601ddd0-3170-4437-a8f7-ef5a060edf5b   2024-09-06         Ford
# 45  11c58ef0-dd46-4c09-8752-87aa5408f9ac   2024-06-27         Ford
# 55  30a900ad-939b-462d-a645-f129629c2ae3   2022-03-21         Ford
# 68  91b0e1d9-9d92-42af-ac8d-0e44e71e43a6   2023-04-15         Ford
#
#       Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# 1    Mustang Mach-E          2017                      33            111
# 44  F-150 Lightning          2017                     119            389
# 45   Mustang Mach-E          2023                     109            381
# 55  F-150 Lightning          2021                      96            284
# 68  F-150 Lightning          2016                      82            176
#
#     Charging_Time_(hours)  Price_(USD)  Buyer_Age Buyer_Gender  \
# ...

# %%
df1=df.loc[(df["Vehicle_Make"]=="BMW")&(df["Payment_Method"]=="Cash")&(df["Customer_Satisfaction_Rating"]<=3)]
df1
# Out:
#                                    Sale_ID Date_of_Sale Vehicle_Make  \
# 15    e87d1c78-e7c4-41c7-8049-7b717d106c60   2024-03-26          BMW
# 74    f5b78cc7-e6b3-4944-8b32-3e357922bac2   2023-09-28          BMW
# 99    c074718e-425a-409f-b337-c59979844388   2025-02-13          BMW
# 185   b0ae8f08-c31e-4bbc-b36c-b62b892e6161   2023-07-02          BMW
# 217   48603b32-b4fb-4eb9-89c1-3de73b4206c5   2024-12-28          BMW
# ...                                    ...          ...          ...
# 3752  ae11d3c2-3130-4c8f-920e-0734564d46aa   2024-03-08          BMW
# 3828  5fcf5c22-b9b0-4c1a-baf9-706d802ddcc4   2023-01-15          BMW
# 3931  ec814510-c42e-4fc8-9372-e80dee892190   2023-04-22          BMW
# 3958  a18e4440-7a70-4cf8-92ef-d363b4dea4a4   2025-01-17          BMW
# 3960  0f0e5767-606f-4a15-b76c-432eb4428cde   2023-12-29          BMW
#
#      Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# ...

# %%
df["Date_of_Sale"]=pd.to_datetime(df["Date_of_Sale"])

# %%
df["Year"]=df["Date_of_Sale"].dt.year

# %%
df
# Out:
#                                    Sale_ID Date_of_Sale Vehicle_Make  \
# 0     19985f15-ff00-4d4d-9020-59e4ff9ab5c2   2023-10-04   Volkswagen
# 1     8181a8cc-3691-47eb-89a2-688b12c136e0   2022-03-31         Ford
# 2     5958a499-eeea-463e-a1e8-ac6843e42caf   2022-09-15          BMW
# 3     3e896c64-e117-4ac3-919c-4ea3e1805081   2022-09-10   Volkswagen
# 4     702cdd20-2862-48b8-88f4-ef125e9953d2   2022-07-19    Chevrolet
# ...                                    ...          ...          ...
# 3995  c69e17c9-6018-4b17-bec5-715ca71db3a6   2022-05-13       Rivian
# 3996  abb558e1-cb9a-4ed5-bdbc-ebdbb119779c   2022-09-17         Ford
# 3997  76b35303-c719-4dd0-96f0-c19ca894b11e   2024-04-11       Nissan
# 3998  61d15db2-a67a-470a-9175-3cd1dd69cf6b   2024-02-25      Hyundai
# 3999  71f34593-a737-419b-a1e0-9bf146748ee4   2023-10-04      Hyundai
#
#        Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# ...

# %%
df["MONTH"]=df["Date_of_Sale"].dt.month_name()

# %%
df.head()
# Out:
#                                 Sale_ID Date_of_Sale Vehicle_Make  \
# 0  19985f15-ff00-4d4d-9020-59e4ff9ab5c2   2023-10-04   Volkswagen
# 1  8181a8cc-3691-47eb-89a2-688b12c136e0   2022-03-31         Ford
# 2  5958a499-eeea-463e-a1e8-ac6843e42caf   2022-09-15          BMW
# 3  3e896c64-e117-4ac3-919c-4ea3e1805081   2022-09-10   Volkswagen
# 4  702cdd20-2862-48b8-88f4-ef125e9953d2   2022-07-19    Chevrolet
#
#     Vehicle_Model  Vehicle_Year  Battery_Capacity_(kWh)  Range_(miles)  \
# 0            ID.4          2021                     107            109
# 1  Mustang Mach-E          2017                      33            111
# 2              iX          2021                      70            362
# 3            ID.4          2022                      74            244
# 4         Bolt EV          2024                      79            291
#
#    Charging_Time_(hours)  Price_(USD)  Buyer_Age Buyer_Gender  \
# 0                    9.8        37517         41       Female
# ...

# %%
df.groupby("Vehicle_Make")["Vehicle_Model"].unique()
# Out:
# Vehicle_Make
# BMW                                   [iX, i4, i3]
# Chevrolet                      [Bolt EV, Bolt EUV]
# Ford             [Mustang Mach-E, F-150 Lightning]
# Hyundai                   [Ioniq 5, Kona Electric]
# Nissan                                      [Leaf]
# Rivian                                  [R1T, R1S]
# Tesla         [Model 3, Model S, Model Y, Model X]
# Volkswagen                                  [ID.4]
# Name: Vehicle_Model, dtype: object

# %%
df.groupby("Year")["Price_(USD)"].unique()
# Out:
# Year
# 2022    [81278, 37620, 61744, 47804, 55568, 69827, 558...
# 2023    [37517, 75426, 61205, 44435, 63526, 86788, 722...
# 2024    [42991, 33912, 55863, 58458, 45407, 81399, 373...
# 2025    [57527, 27355, 77716, 63042, 46500, 82819, 494...
# Name: Price_(USD), dtype: object

# %%
#statistics
import seaborn as sns

# %%
sns.boxplot(x="Vehicle_Make",data=df)
# Out:
# <Axes: xlabel='Vehicle_Make'>

# %%
 sns.boxplot(x="Price_(USD)",data=df)
# Out:
# <Axes: xlabel='Price_(USD)'>

# %%
sns.histplot(df["Price_(USD)"], kde=True)
# Out:
# <Axes: xlabel='Price_(USD)', ylabel='Count'>

# %%
#Matplot lib
import seaborn as sns

# %%
import matplotlib.pyplot as plt
sns.barplot(x="Year",y="Price_(USD)",data=df,estimator=sum)
plt.xlabel("year")
plt.ylabel("price")
plt.show()

# %%
#custamise data in matplotlib 
import seaborn as sns                                
import matplotlib.pyplot as plt
sns.barplot(x="Vehicle_Make",y="Year",data=df,estimator=sum)
plt.xlabel("Make")
plt.ylabel("Month")
plt.show()

# %%
#linechart-tranding
df_new=df.groupby("Year")["Price_(USD)"].sum()
plt.figure(figsize=(10,5))
unique_years=df_new.index
df_new.plot(kind="line",marker="o",color="red",linestyle="--")
plt.xticks(unique_years)
plt.show()

# %%
#pie chart
df_new=df.groupby("Year")["Price_(USD)"].sum()
plt.figure(figsize=(12,6))
df_new.plot(kind='pie',labels=df_new.index,autopct="%1.1f%%")
plt.show()

# %%
#pie chart
df_new=df.groupby("Vehicle_Make")["Year"].sum()
plt.figure(figsize=(12,6))
df_new.plot(kind='pie',labels=df_new.index,autopct="%1.1f%%")
plt.show()
